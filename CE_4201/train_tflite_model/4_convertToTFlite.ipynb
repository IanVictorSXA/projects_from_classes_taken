# %%
import tensorflow as tf

model = tf.keras.models.load_model("best_NN_angle_estimation.keras")

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (32, 287)                   │           2,870 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (32, 287)                   │          82,656 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (32, 287)                   │          82,656 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (32, 287)                   │          82,656 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (32, 287)                   │          82,656 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (32, 6)                     │           1,728 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,005,668 (3.84 MB)
#  Trainable params: 335,222 (1.28 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 670,446 (2.56 MB)

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]

# %%
tflite_model = converter.convert()
# Out:
# INFO:tensorflow:Assets written to: C:\Users\ianvi\AppData\Local\Temp\tmpto2dq2jk\assets
# INFO:tensorflow:Assets written to: C:\Users\ianvi\AppData\Local\Temp\tmpto2dq2jk\assets
# Saved artifact at 'C:\Users\ianvi\AppData\Local\Temp\tmpto2dq2jk'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(32, 9), dtype=tf.float32, name='input_layer')
# Output Type:
#   TensorSpec(shape=(32, 6), dtype=tf.float32, name=None)
# Captures:
#   2997961710608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2997961715024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2997961713872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2997961715792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2997961714640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2997961716752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2997961715408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2997961716944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2997961715984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2997961717328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2997961716176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2997961718288: TensorSpec(shape=(), dtype=tf.resource, name=None)

# %%
with open("model.tflite", "wb") as f:
    f.write(tflite_model)
